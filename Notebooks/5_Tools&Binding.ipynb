# %%
import os
from dotenv import load_dotenv
load_dotenv()
if os.getenv("GROQ_API_KEY"):
    print("API Key Is Set")
else:
    raise ValueError("API Key Not Set")

from langchain_groq import ChatGroq
llm = ChatGroq(model = "openai/gpt-oss-120b")
# Out:
# API Key Is Set

# %%
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_core.messages import AIMessage

duck_search = DuckDuckGoSearchRun(description = "You Are Here To Search On Web")

duck_search.invoke("Who is pm of india")
# Out:
# 'PM expresses pride in Indian contingent’s performance at Commonwealth Games 2026.Shri Narendra Modi was sworn-in as India’s Prime Minister for the third time on 9th June 2024, following another decisive victory in the 2024 Parliamentary elections. The Prime Minister leads the country’s policies and ensures that the government works smoothly. Currently, Narendra Modi is the Prime Minister of India, having been in office since 2014. He is the 14th Prime Minister of India who had three consecutive terms on the post. India’s head of state is the president, whose powers are largely nominal and ceremonial. Effective executive power rests with the Council of Ministers, headed by the prime minister, who is chosen by the majority party or coalition in the Lok Sabha (lower house of parliament) and is formally. Narendra Modi is the PM of India. New questions in Physics. Block A has a mass of 20 kg and block B has a mass of 64 kg. Top Pharmacy Colleges in India.Narendra Damodardas Modi is an Indian politician serving as the 14th and current Prime Minister of India since 2014.'
