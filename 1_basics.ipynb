# %%
import os
from dotenv import load_dotenv

print("loading api key.....")
load_dotenv()

os.getenv("GROQ_API_KEY")
print("API Key Loaded.....")

from langchain.agents import create_agent
from langchain_groq import ChatGroq

print("Creating Agent....")
llm = ChatGroq(model = "openai/gpt-oss-120b")

print("Model Created....")
response = llm.invoke("Hi")
response.content
# Out:
# loading api key.....
# API Key Loaded.....
# Creating Agent....
# Model Created....
# 'Hello! How can I help you today?'

# %%
llm
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.5.2', 'langchain': '1.3.14'}}, output_version=None, profile={'name': 'GPT OSS 120B', 'release_date': '2025-08-05', 'last_updated': '2026-05-27', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x000001CD4193BCE0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001CD421006B0>, model_name='openai/gpt-oss-120b', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %% [markdown]
# ## First Graph

# %% [markdown]
# ### Step-1:Define Schema

# %%
from langgraph.graph import START, END, StateGraph
from typing import TypedDict, List

class graph_schema(TypedDict):
    name : str
    message : str

# %% [markdown]
# ### Step-2 : Create The Node Functions

# %%
def welcome(state:graph_schema)->graph_schema:
    curr_name = state["name"]
    curr_message = state["message"]
    
    response = llm.invoke(f"My Name Is {curr_name}. {curr_message}").content
    state["message"] = f"Your Message Was {curr_message}. Here is My response: {response}" 
    return state
